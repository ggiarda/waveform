# %% [markdown]
# # Data Analysis

# %%
import pysr
from pysr import PySRRegressor

import csv
import numpy as np
import matplotlib.pyplot as plt

from sympy import Piecewise
from IPython.display import display, Math

# %% [markdown]
# ## Data Reading

# %%
# Specify the CSV file path
csv_file_path = 'data.csv'

# Read from CSV and create NumPy arrays
data = np.genfromtxt(csv_file_path, delimiter=',', skip_header=1, dtype=None)

# Extract columns

X = data[:, 0]
y = data[:, 1]
q = data[:, 2]

Xdraw = X

# Use this if you don't want to use q as a feature
        
X = X.reshape(-1, 1)

# Use this if you want to use q as a feature

#X = np.column_stack((X, q))

# %% [markdown]
# ## Model Loading

# %%
model_freq = PySRRegressor.from_file("hall_of_fame_2023-12-26_200829.717.pkl")
# Out:
# Checking if hall_of_fame_2023-12-26_200829.717.pkl exists...
# Loading model from hall_of_fame_2023-12-26_200829.717.pkl

# %% [markdown]
# ## Analysis

# %%
ypred = model_freq.predict(X)

# %%
plt.plot(Xdraw, y, c = "black", label = "Data")
plt.plot(Xdraw, ypred, c = "red", label = "Prediction")
plt.legend()
plt.show()

# %%
print(model_freq)
# Out:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                          -21.37235
# 	1         0.114901                                   (-18.277014 + f)
# 	2         0.075630                   (-25.06399 + cond(f, 10.678444))
# 	3         0.134063        (-25.06399 + cond(f - 2.299517, 10.677911))
# 	4         0.078747  (-25.06399 + cond(f - 2.299517, 10.677911 * 1....
# 	5         0.340499  (-25.06399 + cond(f - 2.364564, (10.677911 - f...
# 	6         0.196302  (-25.06399 + cond(f - 2.364564, ((10.677911 - ...
# 	7         0.200514  (-25.06399 + cond(f - 2.299517, (((10.677911 -...
# 	8         0.072470  (-25.06399 + cond(f - 2.299517, 2.299517 + (((...
# 	9         0.000070  (-25.06399 + cond(f - 2.299517, (((((10.677911...
# 	10        1.443278  ((1.1231501 - ((2.3491006 / 0.17199877) - cond...
# 	11        0.264745  ((1.2692791 - ((2.3491006 / 0.17199877) - cond...
# 	12        0.097520  ((1.2692791 - ((2.3491006 / 0.17199877) - cond...
# 	13        0.001625  (((1.2692791 - ((2.3491006 / 0.17199877) - con...
# 	14        0.342552  ((((1.2692791 + 0.6265036) - ((2.3491006 / 0.1...
# 	15        0.232570  (((((1.2692791 + 0.6265036) - ((2.3491006 / 0....
# 	16        0.029799  (((((1.2692791 + 0.6265036) - ((2.3491006 / 0....
# 	17        0.014726  ((((1.495411 - ((2.3491006 / 0.17199877) - con...
# 	18  >>>>  0.474963  (((((1.2692791 + 0.6265036) - ((2.3491006 / 0....
#
# 	         loss  complexity
# 	0   81.395740           1
# 	1   64.684400           3
# 	2   55.604300           5
# 	3   42.526764           7
# 	4   36.329823           9
# 	5   18.386948          11
# 	6   12.416627          13
# 	7    8.314567          15
# 	8    7.192717          17
# 	9    7.190693          21
# 	10   0.401010          23
# 	11   0.236157          25
# 	12   0.194311          27
# 	13   0.193680          29
# 	14   0.097622          31
# 	15   0.061311          33
# 	16   0.057764          35
# 	17   0.054460          39
# 	18   0.021063          41
# ]

# %%
latex_equation = model_freq.latex()

display(Math(latex_equation))
# Out:
# $\displaystyle 2.11 \operatorname{cond}{\left(-0.591 + \frac{0.337}{-0.455 + \frac{2.36}{f}},14.4 - 0.610 f \right)} - 25.0$

# %%
plt.title("Close-Up")
plt.plot(np.exp(Xdraw), np.exp(y), c = "black", label = "Data")
plt.plot(np.exp(Xdraw), np.exp(ypred), c = "red", label = "Prediction")
plt.legend()
plt.xlim(10,200)
plt.show()
